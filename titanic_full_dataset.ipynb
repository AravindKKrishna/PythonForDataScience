# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"C:\Users\anant\Desktop\titanic (1).csv")
d=dataset
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.shape[1]
# Out:
# 12

# %%
d.shape[0]
# Out:
# 891

# %%
d.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
d['Fare'].mean()
# Out:
# 32.204207968574636

# %%
d.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
 
plt.boxplot(d["Age"]  )
plt.show()

# %%
#outlayer removed for age
Q1 = d["Age"].quantile(0.25)
Q3 = d["Age"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

h = d[(d["Age"] >= lower_bound) & (d["Age"] <= upper_bound)]
plt.boxplot(h['Age'])
plt.title("outlayer removed graph of Age")
plt.ylabel("Value")
plt.show()

# %%
# Calculate IQR for Fare
Q1 = d["Fare"].quantile(0.25)
Q3 = d["Fare"].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers from Fare
df_no_outliers = d[(d["Fare"] >= lower_bound) & (d["Fare"] <= upper_bound)]

# Plot before and after
plt.figure(figsize=(10,5))

# Original Fare boxplot
plt.subplot(1,2,1)
plt.boxplot(d["Fare"].dropna())
plt.title("Original Fare (with outliers)")
plt.ylabel("Fare")

# Outlier removed Fare boxplot
plt.subplot(1,2,2)
plt.boxplot(d["Fare"].dropna())
plt.title("Fare (outliers removed)")

plt.tight_layout()
plt.show()

# %%
d.duplicated().sum()
# Out:
# 0

# %%
# Step 1: Calculate IQR
Q1 = d["Fare"].quantile(0.25)
Q3 = d["Fare"].quantile(0.75)
IQR = Q3 - Q1

# Step 2: Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Remove outliers from the original DataFrame
d = d[(d["Fare"] >= lower_bound) & (d["Fare"] <= upper_bound)]
py.boxplot(d['Fare'])
py.title("outlayer removed graph of fare")
py.ylabel("Fare")
py.show()

# %%
Q1 = d["Age"].quantile(0.25)
Q3 = d["Age"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
print(lower_bound)
upper_bound = Q3 + 1.5 * IQR
print(upper_bound)

p = d[(d["Age"] >= lower_bound) & (d["Age"] <= upper_bound)]
py.boxplot(p['Age'])
py.title("outlayer removed graph of Age")
py.ylabel("Value")
py.show()
# Out:
# -4.0
# 60.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("titanic (1).csv")

# Columns to check for outliers
cols = ["Age", "SibSp", "Parch", "Fare"]

# Copy original for comparison
df_original = df.copy()

# Remove outliers
for col in cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Visualization: Before vs After
plt.figure(figsize=(14,6))

# Before removing outliers
plt.subplot(1,2,1)
df_original[cols].boxplot()
plt.title("Before Outlier Removal")

# After removing outliers
plt.subplot(1,2,2)
df[cols].boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()
