# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\aaron\OneDrive\Desktop\DATASETS\IRIS.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv(r"C:\Users\aaron\OneDrive\Desktop\DATASETS\IRIS.csv")
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x="sepal_length",
    y="sepal_width",
    
    palette="Set1",
    s=70
)

plt.title("Iris Dataset: Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend(title="Species")
plt.show()

# %%
df.drop(["petal_length","petal_width","species" ],inplace=True,axis=1)
df1=df.loc[0:5,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.drop(["petal_length","petal_width","species" ],inplace=True,axis=1)
#       2 df1=df.loc[0:5,:]
#
# NameError: name 'df' is not defined

# %%
print(df1)

plt.figure(figsize=(3,2))
sns.scatterplot(
    data=df1,
    x="sepal_length",
    y="sepal_width",
    
    palette="Set1",
    s=70
)

plt.title("Iris Dataset: Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend(title="Species")
plt.show()
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6
# 5           5.4          3.9
# C:\Users\aaron\AppData\Local\Temp\ipykernel_30904\3422355866.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(
# C:\Users\aaron\AppData\Local\Temp\ipykernel_30904\3422355866.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Species")

# %%
import numpy as np

# If df1 is a pandas DataFrame
np.linalg.norm(df1.values, ord=2)   # L2 norm of the flattened array

# If you want column-wise norms
np.linalg.norm(df1.values, ord=2, axis=0)

# If you want row-wise norms
np.linalg.norm(df1.values, ord=2, axis=1)
# Out:
# array([6.18546684, 5.74543297, 5.68594759, 5.5470713 , 6.16116872,
#        6.66108099])

# %%
a={
   'sepal_length' : [5.1,4.9,4.7,3.0,6.8,6.7,6.5,6.2,5.9], 
   'sepal_width'  : [3.5,3.0,3.2,4.4,2.8,3.0,3.0,3.4,3.0] 
}
b=pd.DataFrame(a)
print(b)
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           3.0          4.4
# 4           6.8          2.8
# 5           6.7          3.0
# 6           6.5          3.0
# 7           6.2          3.4
# 8           5.9          3.0

# %%
sns.scatterplot(b,x="sepal_length",y="sepal_width")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=2)

# %%
# Predict the cluster for each data point
labels = kmeans.fit_predict(b)

# %%
labels
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 0, 0], dtype=int32)

# %%
b["cluster"]=labels
b
# Out:
#    sepal_length  sepal_width  cluster
# 0           5.1          3.5        1
# 1           4.9          3.0        1
# 2           4.7          3.2        1
# 3           3.0          4.4        1
# 4           6.8          2.8        0
# 5           6.7          3.0        0
# 6           6.5          3.0        0
# 7           6.2          3.4        0
# 8           5.9          3.0        0

# %%
sns.scatterplot(b,x="sepal_length",y="sepal_width",hue="cluster")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
b
# Out:
#    sepal_length  sepal_width  cluster
# 0           5.1          3.5        1
# 1           4.9          3.0        1
# 2           4.7          3.2        1
# 3           3.0          4.4        1
# 4           6.8          2.8        0
# 5           6.7          3.0        0
# 6           6.5          3.0        0
# 7           6.2          3.4        0
# 8           5.9          3.0        0

# %%
kmeans.inertia_
# Out:
# 5.425000000000001

# %%
from sklearn.metrics import silhouette_score
labels = kmeans.fit_predict(scaled_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.metrics import silhouette_score
# ----> 2 labels = kmeans.fit_predict(scaled_data)
#
# NameError: name 'kmeans' is not defined
